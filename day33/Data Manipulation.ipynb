# %% [markdown]
# ## Dropping(Deleting) a column

# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("Titanic_data.csv")

# %%
titanic_df.drop('PassengerId', inplace = True,axis=1)

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic_df.drop([0,2,5],axis = 0, inplace= False).head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 1  female  38.0      1      0  PC 17599  71.2833   C85        C
# 3  female  35.0      1      0    113803  53.1000  C123        S
# 4    male  35.0      0      0    373450   8.0500   NaN        S
# 6    male  54.0      0      0     17463  51.8625   E46        S
# 7    male   2.0      3      1    349909  21.0750   NaN        S

# %%
last_name = [name.split(",")[0] for name in titanic_df["Name"]]
last_name
# Out:
# ['Braund',
#  'Cumings',
#  'Heikkinen',
#  'Futrelle',
#  'Allen',
#  'Moran',
#  'McCarthy',
#  'Palsson',
#  'Johnson',
#  'Nasser',
#  'Sandstrom',
#  'Bonnell',
#  'Saundercock',
#  'Andersson',
#  'Vestrom',
#  'Hewlett',
#  'Rice',
#  'Williams',
#  'Vander Planke',
#  'Masselmani',
#  'Fynney',
#  'Beesley',
#  'McGowan',
#  'Sloper',
#  'Palsson',
#  'Asplund',
#  'Emir',
#  'Fortune',
#  "O'Dwyer",
#  'Todoroff',
#  'Uruchurtu',
#  'Spencer',
#  'Glynn',
#  'Wheadon',
#  'Meyer',
#  'Holverson',
#  'Mamee',
#  'Cann',
#  'Vander Planke',
#  'Nicola-Yarred',
#  'Ahlin',
#  'Turpin',
#  'Kraeff',
#  'Laroche',
#  'Devaney',
#  'Rogers',
#  'Lennon',
#  "O'Driscoll",
#  'Samaan',
#  'Arnold-Franchi',
#  'Panula',
#  'Nosworthy',
#  'Harper',
#  'Faunthorpe',
#  'Ostby',
#  'Woolner',
#  'Rugg',
#  'Novel',
#  'West',
#  'Goodwin',
#  'Sirayanian',
#  'Icard',
#  'Harris',
#  'Skoog',
#  'Stewart',
#  'Moubarek',
#  'Nye',
#  'Crease',
#  'Andersson',
#  'Kink',
#  'Jenkin',
# ...

# %%
titanic_df['Last_Name'] = last_name

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Last_Name
# 0     Braund
# 1    Cumings
# 2  Heikkinen
# 3   Futrelle
# 4      Allen

# %%
initial = [titanic_df["Name"][0].split(".")[0].split(",")[-1].strip() for name in titanic_df["Name"]]

# %%
titanic_df["Initial"] = initial

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Last_Name Initial
# 0     Braund      Mr
# 1    Cumings      Mr
# 2  Heikkinen      Mr
# ...

# %%
titanic_df.drop(["Initial","Last_Name"],axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %% [markdown]
# ## Insert new row

# %%
titanic_df.loc[900,:]=[0,3,"Thapa,Mr.Ram","male",22,1,0,32343,6.44,"C80","S","Thapa","Mr"]

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                            Braund, Mr. Owen Harris
# 1         1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     3.0                             Heikkinen, Miss. Laina
# 3         1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     3.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 887       1.0     1.0                       Graham, Miss. Margaret Edith
# 888       0.0     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0     1.0                              Behr, Mr. Karl Howell
# 890       0.0     3.0                                Dooley, Mr. Patrick
# 900       0.0     3.0                                       Thapa,Mr.Ram
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %% [markdown]
# ## Handling Nan or Null Value

# %%
titanic_df.isna().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age          177
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin        687
# Embarked       2
# Last_Name      0
# Initial        0
# dtype: int64

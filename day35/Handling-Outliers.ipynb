# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %%
titanic_df = pd.read_csv("Titanic_data.csv")

# %%
titanic_df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
titanic_df.Embarked.fillna("S")
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
sample = [150,155,160,165,170]
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof = 1)
z_score = (sample - sample_mean)/(sample_std)
for i,z in enumerate(z_score):
    print(f"Data point {i+1}.{sample[i]} has z-score = {z:3f}")
# Out:
# Data point 1.150 has z-score = -1.264911
# Data point 2.155 has z-score = -0.632456
# Data point 3.160 has z-score = 0.000000
# Data point 4.165 has z-score = 0.632456
# Data point 5.170 has z-score = 1.264911

# %%
sample = titanic_df["Age"]
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof = 1)
z_score = abs((sample - sample_mean)/(sample_std))
for i,z in enumerate(z_score):
    print(f"Data point {i+1}.{sample[i]} has z-score = {z:3f}")
titanic_df["Z-score"] = z_score
# Out:
# Data point 1.22.0 has z-score = 0.530005
# Data point 2.38.0 has z-score = 0.571430
# Data point 3.26.0 has z-score = 0.254646
# Data point 4.35.0 has z-score = 0.364911
# Data point 5.35.0 has z-score = 0.364911
# Data point 6.nan has z-score = nan
# Data point 7.54.0 has z-score = 1.672866
# Data point 8.2.0 has z-score = 1.906799
# Data point 9.27.0 has z-score = 0.185807
# Data point 10.14.0 has z-score = 1.080723
# Data point 11.4.0 has z-score = 1.769120
# Data point 12.58.0 has z-score = 1.948225
# Data point 13.20.0 has z-score = 0.667685
# Data point 14.39.0 has z-score = 0.640270
# Data point 15.14.0 has z-score = 1.080723
# Data point 16.55.0 has z-score = 1.741706
# Data point 17.2.0 has z-score = 1.906799
# Data point 18.nan has z-score = nan
# Data point 19.31.0 has z-score = 0.089552
# Data point 20.nan has z-score = nan
# Data point 21.35.0 has z-score = 0.364911
# Data point 22.34.0 has z-score = 0.296072
# Data point 23.15.0 has z-score = 1.011883
# ...

# %%
zscore_thres = 2.5

# %%
titanic_df[titanic_df["Z-score"]>zscore_thres]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked   Z-score
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C  2.843141
# 116  male  70.5      0      0      370369   7.7500   NaN        Q  2.808721
# 493  male  71.0      0      0    PC 17609  49.5042   NaN        C  2.843141
# 630  male  80.0      0      0       27042  30.0000   A23        S  3.462699
# ...

# %%
titanic_df["Z-score"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
zscore = scipy.stats.zscore(titanic_df.Age.to_numpy(),ddof = 1)

# %%
titanic_df.Age.to_nuumpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3296\1651531097.py in ?()
# ----> 1 titanic_df.Age.to_nuumpy()
#
# ~\Desktop\Python\myenv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_nuumpy'

# %% [markdown]
# **PANDAS**
# -

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ## Datatype of Pandas:
# 1. Dataframe: 2D table with rows and column
# 2. Series: 1D array-like, can hold any type of data

# %% [markdown]
# ## Creating Dataframe:

# %%
data = {
    "name":["RAM","SHYAM","BOB"],
    "age":[21,22,24]
}
data
# Out:
# {'name': ['RAM', 'SHYAM', 'BOB'], 'age': [21, 22, 24]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     name  age
# 0    RAM   21
# 1  SHYAM   22
# 2    BOB   24

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
arr_data = np.array(
    [
        ["Ram",25],
        ["Shyam",22],
        ["Bob",33]
    ]
)

# %%
pd.DataFrame(arr_data,columns = ["Name","Age"])
# Out:
#     Name Age
# 0    Ram  25
# 1  Shyam  22
# 2    Bob  33

# %% [markdown]
# **Reading Data from Files**
# -
#
# ```python
# pd.read_csv(file_path, delimiter = ',')

# %%
df = pd.read_csv("Titanic_data.csv",delimiter=',',header = 0) #header = 0 means our column name or header is in 0th line

# %%
df.head(25)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Accessing Data

# %%
name = df["Name"]

# %%
name.shape #single dimension --> so called, series not dataframe
# Out:
# (891,)

# %%
name.head(15)
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
name_age = df[["Name","Age"]]

# %%
name_age
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
name_age.shape #multi dimension(got both columns and rows) so dataframe
# Out:
# (891, 2)

# %%
df.columns #returns all the columns on the dataset
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

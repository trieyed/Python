# %%
# !pip install scipy
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Bar Graph

# %%
titanic_df = pd.read_csv("Titanic_data.csv")

# %%
titanic_df['Survived'].value_counts().plot(
    kind = 'bar',legend = True,
    title = "Count of survived passangers",grid = True,
    fontsize = 18,
    colormap = "tab20c"
)
# Out:
# <Axes: title={'center': 'Count of survived passangers'}, xlabel='Survived'>

# %%
group_by_gender = titanic_df[["Sex","Survived"]].groupby(by="Sex")

# %%
group_by_gender.value_counts().plot(kind = "bar",legend = True,colormap = "Dark2")
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
group_by_embarked = titanic_df[['Embarked','Age']].groupby(by=['Embarked'])
group_by_embarked.mean().plot(kind = "bar",colormap = "Dark2")
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# ## Pie Chart

# %%
titanic_df['Survived'].value_counts().plot(
    kind = 'pie',legend = True,
    title = "Count of survived passangers",grid = True,
    fontsize = 18,
    colormap = "tab20c"
)
# Out:
# <Axes: title={'center': 'Count of survived passangers'}, ylabel='count'>

# %%
group_by_gender.value_counts().plot(kind = "pie",colormap = "Pastel1")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Line Graph

# %%
titanic_df.loc[:10,"Fare"].plot(kind = "line")
# Out:
# <Axes: >

# %% [markdown]
# ## Scatter Plot (x,y)

# %%
titanic_df.plot.scatter("Age","Fare")
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ## Histogram

# %%
titanic_df.Age.plot.hist(bins=8,grid= True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic_df.Age.plot.kde(ind = np.linspace(0,80,500),grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Box Plot

# %%
titanic_df.Age.plot.box()
# Out:
# <Axes: >

# %%
titanic_df.plot.box(column = "Age", by = "Sex")
# Out:
# Age    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# ## Heatmap

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
correlation = titanic_df[["Pclass","Age","Fare","SibSp"]].corr()
correlation
# Out:
#           Pclass       Age      Fare     SibSp
# Pclass  1.000000 -0.369226 -0.549500  0.083081
# Age    -0.369226  1.000000  0.096067 -0.308247
# Fare   -0.549500  0.096067  1.000000  0.159651
# SibSp   0.083081 -0.308247  0.159651  1.000000

# %%
sns.heatmap(correlation, annot = True, cmap = "coolwarm",robust=True)
# Out:
# <Axes: >
